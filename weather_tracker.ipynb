# %% [markdown]
# ## Weather Tracker Demo
# This file will contain the demo content for our weather tracker

# %%
#Main menu items
import my_weather_tacker as wt

# %%
wt.init_csv()
# Out:
# Loaded existing csv file: observations.csv

# %%
wt.load_observations()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 wt.load_observations()
#
# TypeError: load_observations() missing 1 required positional argument: 'self'

# %%
wt.search()
# Out:
# data file not found
